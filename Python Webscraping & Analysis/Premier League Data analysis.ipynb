# %%
import pandas as pd

# %%
df1 = pd.read_csv(r'/Users/joebeadles/Desktop/prem_data/prem_2021_to_2022.csv', encoding='ISO-8859-1')
print(df1.head())
# Out:
#    GW  Day       Date         Time            Home  xG_H Score  xG_A  \
# 0   1  Fri  8/13/2021   8:00:00 PM       Brentford   1.2   20   1.3
# 1   1  Sat  8/14/2021  12:30:00 PM  Manchester Utd   1.5   51   0.5
# 2   1  Sat  8/14/2021   3:00:00 PM  Leicester City   0.5   10   1.3
# 3   1  Sat  8/14/2021   3:00:00 PM         Burnley   1.5   12   1.0
# 4   1  Sat  8/14/2021   3:00:00 PM         Chelsea   0.7   30   0.2
#
#              Away  Attendance                        Venue         Referee
# 0         Arsenal       16479  Brentford Community Stadium  Michael Oliver
# 1    Leeds United       72732                 Old Trafford    Paul Tierney
# 2          Wolves       31983           King Power Stadium    Craig Pawson
# 3        Brighton       16910                    Turf Moor     David Coote
# 4  Crystal Palace       38965              Stamford Bridge   Jonathan Moss

# %%
df2 = pd.read_csv(r'/Users/joebeadles/Desktop/prem_data/prem_2022_to_2023.csv', encoding='ISO-8859-1')
print(df2.head())
# Out:
#    GW  Day      Date         Time            Home  xG_H Score  xG_A  \
# 0   1  Fri  8/5/2022   8:00:00 PM  Crystal Palace   1.2   02   1.0
# 1   1  Sat  8/6/2022  12:30:00 PM          Fulham   1.2   22   1.2
# 2   1  Sat  8/6/2022   3:00:00 PM       Tottenham   1.5   41   0.5
# 3   1  Sat  8/6/2022   3:00:00 PM   Newcastle Utd   1.7   20   0.3
# 4   1  Sat  8/6/2022   3:00:00 PM    Leeds United   0.8   21   1.3
#
#               Away  Attendance                      Venue         Referee
# 0          Arsenal     25286.0              Selhurst Park  Anthony Taylor
# 1        Liverpool     22207.0             Craven Cottage     Andy Madley
# 2      Southampton     61732.0  Tottenham Hotspur Stadium  Andre Marriner
# 3  Nott'ham Forest     52245.0             St James' Park    Simon Hooper
# 4           Wolves     36347.0                Elland Road    Robert Jones

# %%
df3 = pd.read_csv(r'/Users/joebeadles/Desktop/prem_data/prem_2023_to_2024.csv', encoding='ISO-8859-1')
print(df3.head())
# Out:
#    GW  Day       Date         Time           Home  xG_H Score  xG_A  \
# 0   1  Fri  8/11/2023   8:00:00 PM        Burnley   0.3   03   1.9
# 1   1  Sat  8/12/2023  12:30:00 PM        Arsenal   0.8   21   1.2
# 2   1  Sat  8/13/2023   3:00:00 PM        Everton   2.7   01   1.5
# 3   1  Sat  8/14/2023   3:00:00 PM  Sheffield Utd   0.5   01   1.9
# 4   1  Sat  8/15/2023   3:00:00 PM       Brighton   4.0   41   1.5
#
#               Away  Attendance                                   Venue  \
# 0  Manchester City       21572                               Turf Moor
# 1  Nott'ham Forest       59984                        Emirates Stadium
# 2           Fulham       39940                           Goodison Park
# 3   Crystal Palace       31194                            Bramall Lane
# 4       Luton Town       31872  The American Express Community Stadium
#
#           Referee
# 0    Craig Pawson
# 1  Michael Oliver
# 2  Stuart Attwell
# 3     John Brooks
# 4     David Coote

# %%
combined_data = pd.concat([df1, df2, df3], ignore_index=True)
print(combined_data)
# Out:
#       GW  Day       Date         Time            Home  xG_H Score  xG_A  \
# 0      1  Fri  8/13/2021   8:00:00 PM       Brentford   1.2   20   1.3
# 1      1  Sat  8/14/2021  12:30:00 PM  Manchester Utd   1.5   51   0.5
# 2      1  Sat  8/14/2021   3:00:00 PM  Leicester City   0.5   10   1.3
# 3      1  Sat  8/14/2021   3:00:00 PM         Burnley   1.5   12   1.0
# 4      1  Sat  8/14/2021   3:00:00 PM         Chelsea   0.7   30   0.2
# ...   ..  ...        ...          ...             ...   ...   ...   ...
# 1135  38  Sun  8/20/2024   4:00:00 PM       Brentford   1.1   24   3.4
# 1136  38  Sun  8/21/2024   4:00:00 PM         Chelsea   1.1   21   2.2
# 1137  38  Sun  8/22/2024   4:00:00 PM  Crystal Palace   2.5   50   0.9
# 1138  38  Sun  8/23/2024   4:00:00 PM       Liverpool   4.5   20   0.5
# 1139  38  Sun  8/24/2024   4:00:00 PM         Burnley   1.2   12   1.7
#
#                  Away  Attendance                        Venue         Referee
# 0             Arsenal     16479.0  Brentford Community Stadium  Michael Oliver
# 1        Leeds United     72732.0                 Old Trafford    Paul Tierney
# 2              Wolves     31983.0           King Power Stadium    Craig Pawson
# 3            Brighton     16910.0                    Turf Moor     David Coote
# 4      Crystal Palace     38965.0              Stamford Bridge   Jonathan Moss
# ...               ...         ...                          ...             ...
# 1135    Newcastle Utd     17124.0      Gtech Community Stadium    Simon Hooper
# 1136      Bournemouth     39724.0              Stamford Bridge  Anthony Taylor
# 1137      Aston Villa     25191.0                Selhurst Park     Darren Bond
# 1138           Wolves     60059.0                      Anfield  Chris Kavanagh
# 1139  Nott'ham Forest     21109.0                    Turf Moor    Graham Scott
#
# [1140 rows x 12 columns]

# %%
# Lets explore our data
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print(combined_data.shape)
print(combined_data.columns)
print(combined_data.dtypes)
# Out:
# (1140, 12)
# Index(['GW', 'Day', 'Date', 'Time', 'Home', 'xG_H', 'Score', 'xG_A', 'Away',
#        'Attendance', 'Venue', 'Referee'],
#       dtype='object')
# GW              int64
# Day            object
# Date           object
# Time           object
# Home           object
# xG_H          float64
# Score          object
# xG_A          float64
# Away           object
# Attendance    float64
# Venue          object
# Referee        object
# dtype: object

# %%
# Everything looks good except for the date and time columns, lets take a look and change them.
print(combined_data.head())
print(combined_data.tail())
# Out:
#    GW  Day       Date         Time            Home  xG_H Score  xG_A  \
# 0   1  Fri  8/13/2021   8:00:00 PM       Brentford   1.2   20   1.3
# 1   1  Sat  8/14/2021  12:30:00 PM  Manchester Utd   1.5   51   0.5
# 2   1  Sat  8/14/2021   3:00:00 PM  Leicester City   0.5   10   1.3
# 3   1  Sat  8/14/2021   3:00:00 PM         Burnley   1.5   12   1.0
# 4   1  Sat  8/14/2021   3:00:00 PM         Chelsea   0.7   30   0.2
#
#              Away  Attendance                        Venue         Referee
# 0         Arsenal     16479.0  Brentford Community Stadium  Michael Oliver
# 1    Leeds United     72732.0                 Old Trafford    Paul Tierney
# 2          Wolves     31983.0           King Power Stadium    Craig Pawson
# 3        Brighton     16910.0                    Turf Moor     David Coote
# 4  Crystal Palace     38965.0              Stamford Bridge   Jonathan Moss
#       GW  Day       Date        Time            Home  xG_H Score  xG_A  \
# 1135  38  Sun  8/20/2024  4:00:00 PM       Brentford   1.1   24   3.4
# 1136  38  Sun  8/21/2024  4:00:00 PM         Chelsea   1.1   21   2.2
# 1137  38  Sun  8/22/2024  4:00:00 PM  Crystal Palace   2.5   50   0.9
# 1138  38  Sun  8/23/2024  4:00:00 PM       Liverpool   4.5   20   0.5
# 1139  38  Sun  8/24/2024  4:00:00 PM         Burnley   1.2   12   1.7
#
#                  Away  Attendance                    Venue         Referee
# 1135    Newcastle Utd     17124.0  Gtech Community Stadium    Simon Hooper
# 1136      Bournemouth     39724.0          Stamford Bridge  Anthony Taylor
# 1137      Aston Villa     25191.0            Selhurst Park     Darren Bond
# 1138           Wolves     60059.0                  Anfield  Chris Kavanagh
# 1139  Nott'ham Forest     21109.0                Turf Moor    Graham Scott

# %%
combined_data['Converted_Date'] = pd.to_datetime(combined_data['Date'], format = '%m/%d/%Y')
print('Converted Date column')
print(combined_data)


print(combined_data.dtypes)
# Out:
# Converted Date column
#       GW  Day       Date         Time            Home  xG_H Score  xG_A  \
# 0      1  Fri  8/13/2021   8:00:00 PM       Brentford   1.2   20   1.3
# 1      1  Sat  8/14/2021  12:30:00 PM  Manchester Utd   1.5   51   0.5
# 2      1  Sat  8/14/2021   3:00:00 PM  Leicester City   0.5   10   1.3
# 3      1  Sat  8/14/2021   3:00:00 PM         Burnley   1.5   12   1.0
# 4      1  Sat  8/14/2021   3:00:00 PM         Chelsea   0.7   30   0.2
# ...   ..  ...        ...          ...             ...   ...   ...   ...
# 1135  38  Sun  8/20/2024   4:00:00 PM       Brentford   1.1   24   3.4
# 1136  38  Sun  8/21/2024   4:00:00 PM         Chelsea   1.1   21   2.2
# 1137  38  Sun  8/22/2024   4:00:00 PM  Crystal Palace   2.5   50   0.9
# 1138  38  Sun  8/23/2024   4:00:00 PM       Liverpool   4.5   20   0.5
# 1139  38  Sun  8/24/2024   4:00:00 PM         Burnley   1.2   12   1.7
#
#                  Away  Attendance                        Venue  \
# 0             Arsenal     16479.0  Brentford Community Stadium
# 1        Leeds United     72732.0                 Old Trafford
# 2              Wolves     31983.0           King Power Stadium
# 3            Brighton     16910.0                    Turf Moor
# 4      Crystal Palace     38965.0              Stamford Bridge
# ...               ...         ...                          ...
# 1135    Newcastle Utd     17124.0      Gtech Community Stadium
# 1136      Bournemouth     39724.0              Stamford Bridge
# 1137      Aston Villa     25191.0                Selhurst Park
# 1138           Wolves     60059.0                      Anfield
# 1139  Nott'ham Forest     21109.0                    Turf Moor
#
#              Referee Converted_Date
# 0     Michael Oliver     2021-08-13
# 1       Paul Tierney     2021-08-14
# 2       Craig Pawson     2021-08-14
# 3        David Coote     2021-08-14
# 4      Jonathan Moss     2021-08-14
# ...              ...            ...
# 1135    Simon Hooper     2024-08-20
# 1136  Anthony Taylor     2024-08-21
# 1137     Darren Bond     2024-08-22
# 1138  Chris Kavanagh     2024-08-23
# 1139    Graham Scott     2024-08-24
#
# [1140 rows x 13 columns]
# GW                         int64
# Day                       object
# Date                      object
# Time                      object
# Home                      object
# xG_H                     float64
# Score                     object
# xG_A                     float64
# Away                      object
# Attendance               float64
# Venue                     object
# Referee                   object
# Converted_Date    datetime64[ns]
# dtype: object

# %%
combined_data['Year'] = combined_data['Converted_Date'].dt.year
print('Extracted Year: ')
print(combined_data[['Date', 'Converted_Date', 'Year']])
# Out:
# Extracted Year:
#            Date Converted_Date  Year
# 0     8/13/2021     2021-08-13  2021
# 1     8/14/2021     2021-08-14  2021
# 2     8/14/2021     2021-08-14  2021
# 3     8/14/2021     2021-08-14  2021
# 4     8/14/2021     2021-08-14  2021
# ...         ...            ...   ...
# 1135  8/20/2024     2024-08-20  2024
# 1136  8/21/2024     2024-08-21  2024
# 1137  8/22/2024     2024-08-22  2024
# 1138  8/23/2024     2024-08-23  2024
# 1139  8/24/2024     2024-08-24  2024
#
# [1140 rows x 3 columns]

# %%
combined_data['Score'] = combined_data['Score'].str.replace('\x96', '-', regex=False)

# %%
# We can use str.split to extract the actual goals scored for the home and away teams in the game.
combined_data['Home_Score'] = combined_data['Score'].str.split('-').str[0].astype(int)
combined_data['Away_Score'] = combined_data['Score'].str.split('-').str[1].astype(int)
print(combined_data.head())
# Out:
#    GW  Day       Date         Time            Home  xG_H Score  xG_A  \
# 0   1  Fri  8/13/2021   8:00:00 PM       Brentford   1.2   2-0   1.3
# 1   1  Sat  8/14/2021  12:30:00 PM  Manchester Utd   1.5   5-1   0.5
# 2   1  Sat  8/14/2021   3:00:00 PM  Leicester City   0.5   1-0   1.3
# 3   1  Sat  8/14/2021   3:00:00 PM         Burnley   1.5   1-2   1.0
# 4   1  Sat  8/14/2021   3:00:00 PM         Chelsea   0.7   3-0   0.2
#
#              Away  Attendance                        Venue         Referee  \
# 0         Arsenal     16479.0  Brentford Community Stadium  Michael Oliver
# 1    Leeds United     72732.0                 Old Trafford    Paul Tierney
# 2          Wolves     31983.0           King Power Stadium    Craig Pawson
# 3        Brighton     16910.0                    Turf Moor     David Coote
# 4  Crystal Palace     38965.0              Stamford Bridge   Jonathan Moss
#
#   Converted_Date  Year  Home_Score  Away_Score
# 0     2021-08-13  2021           2           0
# 1     2021-08-14  2021           5           1
# 2     2021-08-14  2021           1           0
# 3     2021-08-14  2021           1           2
# 4     2021-08-14  2021           3           0

# %%
print(combined_data.describe())
# Out:
#                 GW         xG_H         xG_A    Attendance  \
# count  1140.000000  1140.000000  1140.000000   1139.000000
# mean     19.500000     1.598333     1.273421  39459.472344
# min       1.000000     0.000000     0.000000   9972.000000
# 25%      10.000000     0.900000     0.700000  27016.000000
# 50%      19.500000     1.500000     1.100000  36740.000000
# 75%      29.000000     2.200000     1.700000  53130.500000
# max      38.000000     7.000000     4.600000  75546.000000
# std      10.970669     0.882742     0.779356  16636.220958
#
#                       Converted_Date         Year   Home_Score   Away_Score
# count                           1140  1140.000000  1140.000000  1140.000000
# mean   2023-01-21 15:17:03.157894656  2022.570175     1.649123     1.334211
# min              2021-08-13 00:00:00  2021.000000     0.000000     0.000000
# 25%              2022-03-18 18:00:00  2022.000000     1.000000     0.000000
# 50%              2023-01-21 00:00:00  2023.000000     1.000000     1.000000
# 75%              2023-11-13 06:00:00  2023.000000     2.000000     2.000000
# max              2024-08-24 00:00:00  2024.000000     9.000000     8.000000
# std                              NaN     0.991352     1.375073     1.244361

# %%
print(combined_data.isnull().sum())
# Out:
# GW                0
# Day               0
# Date              0
# Time              0
# Home              0
# xG_H              0
# Score             0
# xG_A              0
# Away              0
# Attendance        1
# Venue             0
# Referee           0
# Converted_Date    0
# Year              0
# Home_Score        0
# Away_Score        0
# dtype: int64

# %%
missing_row = combined_data.loc[combined_data.isnull().any(axis=1)]
print(missing_row)
# Out:
#      GW  Day       Date        Time         Home  xG_H Score  xG_A      Away  \
# 757  38  Sun  5/28/2023  4:30:00 PM  Aston Villa   2.8   2-1   1.4  Brighton
#
#      Attendance       Venue      Referee Converted_Date  Year  Home_Score  \
# 757         NaN  Villa Park  David Coote     2023-05-28  2023           2
#
#      Away_Score
# 757           1

# %%
# We can populate the cell with the attendance at the game after some research. 
atten_value = 42212

# %%
combined_data['Attendance'] = combined_data['Attendance'].fillna(value=atten_value)

# %%
# Lets double check our work
matching_value = combined_data[combined_data['Attendance'] == 42212]
print(matching_value)
# Out:
#      GW  Day       Date        Time         Home  xG_H Score  xG_A      Away  \
# 757  38  Sun  5/28/2023  4:30:00 PM  Aston Villa   2.8   2-1   1.4  Brighton
#
#      Attendance       Venue      Referee Converted_Date  Year  Home_Score  \
# 757     42212.0  Villa Park  David Coote     2023-05-28  2023           2
#
#      Away_Score
# 757           1

# %%
# Home xG

combined_data['xG_H'].hist(bins=30)
plt.title('Home xG Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# Away xG


combined_data['xG_A'].hist(bins=30)
plt.title('Away xG Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# The distributions are similar for both home and away xG; however home teams recorded instances of over 5.0 xG in a single game.
# There is a maximum value of around 7.0 xG in the home distribution.
# There is a maximum value of around 4.7 xG in the away distribution.

# %%
sns.histplot(combined_data['Attendance'])
plt.show()

# %%
# How many games did our referees manage?
ref_counts = combined_data['Referee'].value_counts()
ordered_refs = ref_counts.index

sns.countplot(x='Referee', data=combined_data, order=ordered_refs)
plt.title('Total Games as center ref')
plt.xticks(rotation=60,ha='right')
plt.show()

# %%
# Which refs were involved in games with the most xG?
total_xg_by_ref = combined_data.groupby('Referee').agg(Total_xG_H=('xG_H', 'sum'), Total_xG_A=('xG_A', 'sum')).reset_index()
total_xg_by_ref['Total_xG'] = total_xg_by_ref['Total_xG_H'] + total_xg_by_ref['Total_xG_A']
print(total_xg_by_ref.sort_values('Total_xG', ascending=False))
# Out:
#               Referee  Total_xG_H  Total_xG_A  Total_xG
# 2      Anthony Taylor       142.1       112.0     254.1
# 17     Michael Oliver       144.9       100.6     245.5
# 20       Paul Tierney       125.3       117.7     243.0
# 27       Simon Hooper       119.4        90.7     210.1
# 1         Andy Madley       107.1        81.5     188.6
# 28     Stuart Attwell       109.5        74.1     183.6
# 23       Robert Jones        96.5        79.3     175.8
# 4        Craig Pawson        82.7        85.0     167.7
# 7         David Coote        88.4        67.0     155.4
# 3      Chris Kavanagh        86.3        67.3     153.6
# 9      Jarred Gillett        69.6        66.5     136.1
# 6      Darren England        76.4        58.7     135.1
# 10        John Brooks        67.1        53.1     120.2
# 21       Peter Bankes        57.7        47.7     105.4
# 18  Michael Salisbury        53.3        44.5      97.8
# 0      Andre Marriner        48.9        46.1      95.0
# 15    Martin Atkinson        38.6        34.4      73.0
# 19          Mike Dean        36.9        30.7      67.6
# 31       Tim Robinson        40.3        25.5      65.8
# 11      Jonathan Moss        40.4        25.3      65.7
# 8        Graham Scott        34.4        25.4      59.8
# 30     Thomas Bramall        28.6        22.4      51.0
# 13       Kevin Friend        26.8        23.0      49.8
# 32    Tony Harrington        28.3        21.1      49.4
# 26     Samuel Barrott        25.0        20.9      45.9
# 5         Darren Bond        14.9        14.2      29.1
# 12       Joshua Smith        10.6         5.2      15.8
# 25     Samuel Allison         5.9         3.6       9.5
# 24      Robert Madley         4.3         2.7       7.0
# 14        Lewis Smith         3.9         1.6       5.5
# 16       Matt Donohue         2.7         2.2       4.9
# 22      Rebecca Welch         2.6         0.9       3.5
# 29        Sunny Singh         2.7         0.8       3.5

# %%
# Correlation Matrix with our numerical values
# Could higher attendance result in higher accumulated xG?
numerical_cols = combined_data[['xG_H', 'xG_A', 'Attendance']]
correlation_matrix = numerical_cols.corr()
print(correlation_matrix)
# Out:
#                 xG_H      xG_A  Attendance
# xG_H        1.000000 -0.262482    0.289294
# xG_A       -0.262482  1.000000   -0.157497
# Attendance  0.289294 -0.157497    1.000000

# %%
# Our correlations are not strong enough to support any definitive conclusions. While there is a weak positive correlation 
# between attendance and xG_H, it is not sufficient.
# Additionally, there are multiple factors influencing xG statistics 
# including chances not captured by the xG model and the difficulty of opponents.

# %%
# Home xG and Away xG per team
home_xg = combined_data.groupby('Home')['xG_H'].sum().reset_index()
home_xg.columns = ['Team', 'Total_xG_H']

away_xg = combined_data.groupby('Away')['xG_A'].sum().reset_index()
away_xg.columns = ['Team', 'Total_xG_A']

total_xg = pd.merge(home_xg, away_xg, on='Team', how='outer').fillna(0)

total_xg['Total_xG'] = total_xg['Total_xG_H'] + total_xg['Total_xG_A']

print(total_xg.sort_values(by='Total_xG', ascending=False))
# Out:
#                Team  Total_xG_H  Total_xG_A  Total_xG
# 12        Liverpool       144.5       103.5     248.0
# 14  Manchester City       128.9       118.9     247.8
# 0           Arsenal       123.2        84.9     208.1
# 6           Chelsea       105.0        82.3     187.3
# 21        Tottenham       103.9        82.5     186.4
# 16    Newcastle Utd       111.1        75.2     186.3
# 15   Manchester Utd       103.6        76.1     179.7
# 4          Brighton        98.1        78.0     176.1
# 3         Brentford        89.0        71.5     160.5
# 1       Aston Villa        91.8        65.8     157.6
# 23         West Ham        81.7        71.4     153.1
# 8           Everton        78.9        61.3     140.2
# 7    Crystal Palace        75.7        58.5     134.2
# 24           Wolves        63.9        57.7     121.6
# 11   Leicester City        47.6        51.0      98.6
# 9            Fulham        52.3        44.8      97.1
# 2       Bournemouth        49.3        44.9      94.2
# 10     Leeds United        50.4        40.9      91.3
# 18  Nott'ham Forest        48.4        41.1      89.5
# 20      Southampton        42.4        40.2      82.6
# 5           Burnley        45.3        35.1      80.4
# 13       Luton Town        25.8        16.5      42.3
# 22          Watford        19.8        20.1      39.9
# 19    Sheffield Utd        24.3        14.3      38.6
# 17     Norwich City        17.2        15.2      32.4

# %%
# Grouping Total xG by Year 
home_xg = combined_data.groupby(['Year', 'Home'])['xG_H'].sum().reset_index()
home_xg.columns = ['Year', 'Team', 'Total_xG_H']

# Group by Year and Away team to calculate away xG
away_xg = combined_data.groupby(['Year', 'Away'])['xG_A'].sum().reset_index()
away_xg.columns = ['Year', 'Team', 'Total_xG_A']

# Merge the two DataFrames
total_xg = pd.merge(home_xg, away_xg, on=['Year', 'Team'], how='outer').fillna(0)

# Calculate Total xG
total_xg['Total_xG'] = total_xg['Total_xG_H'] + total_xg['Total_xG_A']

# Display the results
print(total_xg.sort_values(by=['Year', 'Total_xG'], ascending=[True, False]))
# Out:
#     Year             Team  Total_xG_H  Total_xG_A  Total_xG
# 10  2021        Liverpool        22.8        25.1      47.9
# 11  2021  Manchester City        25.3        21.0      46.3
# 5   2021          Chelsea        19.2        15.8      35.0
# 0   2021          Arsenal        17.2        12.5      29.7
# 12  2021   Manchester Utd        14.9        13.0      27.9
# ..   ...              ...         ...         ...       ...
# 69  2024        Brentford        14.8        17.0      31.8
# 77  2024       Luton Town        18.0         9.8      27.8
# 85  2024           Wolves        14.6        13.0      27.6
# 71  2024          Burnley        14.2        12.8      27.0
# 82  2024    Sheffield Utd        16.8         9.9      26.7
#
# [86 rows x 5 columns]

# %%
# Home xG
sns.stripplot(data=combined_data, x='Home', y='xG_H',jitter=True, color='blue')
plt.title('Home xG by Team')
plt.ylabel('Home xG')
plt.xlabel('Teams')
plt.xticks(rotation=90)
plt.show()

# %%
# Away xG
sns.stripplot(data=combined_data, x='Away', y='xG_A',jitter=True, color='red')
plt.title('Away xG by Team')
plt.ylabel('Away xG')
plt.xlabel('Teams')
plt.xticks(rotation=90)
plt.show()

# %%
# This plot allows us to see that Away xG was significantly lower than Home xG in our dataset.
# Additionally, three home teams generated over 5.0 xG, while no away teams reached this mark,
# with the highest away xG being at around 4.7-4.8.

# %%
# Which teams have the highest overall average expected goals?
home_perform = combined_data.groupby('Home')['xG_H'].mean().reset_index()
home_perform.rename(columns={'xG_H': 'Average_xG_H'}, inplace=True)
away_perform = combined_data.groupby('Away')['xG_A'].mean().reset_index()
away_perform.rename(columns={'xG_A': 'Average_xG_A'}, inplace=True)

performance = pd.merge(home_perform, away_perform, left_on='Home', right_on='Away', how='outer')
performance.drop(columns='Away', inplace=True)

performance['Overall'] = performance[['Average_xG_H','Average_xG_A']].mean(axis=1)

print(performance)
# Out:
#                Home  Average_xG_H  Average_xG_A   Overall
# 0           Arsenal      2.161404      1.489474  1.825439
# 1       Aston Villa      1.610526      1.154386  1.382456
# 2       Bournemouth      1.297368      1.181579  1.239474
# 3         Brentford      1.561404      1.254386  1.407895
# 4          Brighton      1.721053      1.368421  1.544737
# 5           Burnley      1.192105      0.923684  1.057895
# 6           Chelsea      1.842105      1.443860  1.642982
# 7    Crystal Palace      1.328070      1.026316  1.177193
# 8           Everton      1.384211      1.075439  1.229825
# 9            Fulham      1.376316      1.178947  1.277632
# 10     Leeds United      1.326316      1.076316  1.201316
# 11   Leicester City      1.252632      1.342105  1.297368
# 12        Liverpool      2.535088      1.815789  2.175439
# 13       Luton Town      1.357895      0.868421  1.113158
# 14  Manchester City      2.261404      2.085965  2.173684
# 15   Manchester Utd      1.817544      1.335088  1.576316
# 16    Newcastle Utd      1.949123      1.319298  1.634211
# 17     Norwich City      0.905263      0.800000  0.852632
# 18  Nott'ham Forest      1.273684      1.081579  1.177632
# 19    Sheffield Utd      1.278947      0.752632  1.015789
# 20      Southampton      1.115789      1.057895  1.086842
# 21        Tottenham      1.822807      1.447368  1.635088
# 22          Watford      1.042105      1.057895  1.050000
# 23         West Ham      1.433333      1.252632  1.342982
# 24           Wolves      1.121053      1.012281  1.066667

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=performance, x='Average_xG_H', y='Average_xG_A', size='Overall', sizes=(10, 100), legend=None)
for i in range(performance.shape[0]):
    plt.text(performance['Average_xG_H'][i] + 0.05,
             performance['Average_xG_A'][i] + 0.05,
             performance['Home'][i],
             horizontalalignment='right',
             size='medium',
             color='black')

# %%
# Manchester City and Liverpool dominate the scatterplot, 
# generating upwards of 2.4 xG at home (Liverpool) and 2.0 xG in away games (Manchester City)

# %%
# Which teams are performing better at home compared to away?
performance['Better_Performance'] = performance.apply(
    lambda row: 'Home' if row['Average_xG_H'] > row['Average_xG_A'] 
                 else ('Away' if row['Average_xG_A'] > row['Average_xG_H'] 
                       else 'Equal'),
    axis=1
)
# Display the results
print(performance[['Home', 'Average_xG_H', 'Average_xG_A', 'Better_Performance']])
# Out:
#                Home  Average_xG_H  Average_xG_A Better_Performance
# 0           Arsenal      2.161404      1.489474               Home
# 1       Aston Villa      1.610526      1.154386               Home
# 2       Bournemouth      1.297368      1.181579               Home
# 3         Brentford      1.561404      1.254386               Home
# 4          Brighton      1.721053      1.368421               Home
# 5           Burnley      1.192105      0.923684               Home
# 6           Chelsea      1.842105      1.443860               Home
# 7    Crystal Palace      1.328070      1.026316               Home
# 8           Everton      1.384211      1.075439               Home
# 9            Fulham      1.376316      1.178947               Home
# 10     Leeds United      1.326316      1.076316               Home
# 11   Leicester City      1.252632      1.342105               Away
# 12        Liverpool      2.535088      1.815789               Home
# 13       Luton Town      1.357895      0.868421               Home
# 14  Manchester City      2.261404      2.085965               Home
# 15   Manchester Utd      1.817544      1.335088               Home
# 16    Newcastle Utd      1.949123      1.319298               Home
# 17     Norwich City      0.905263      0.800000               Home
# 18  Nott'ham Forest      1.273684      1.081579               Home
# 19    Sheffield Utd      1.278947      0.752632               Home
# 20      Southampton      1.115789      1.057895               Home
# 21        Tottenham      1.822807      1.447368               Home
# 22          Watford      1.042105      1.057895               Away
# 23         West Ham      1.433333      1.252632               Home
# 24           Wolves      1.121053      1.012281               Home

# %%
print("""Both Watford and Leicester City are notable as they generated more xG away from home. Despite this, 
in our dataset they are some of the teams to have been relegated (Watford having one season of data and Leicester City 
having two seasons of data. This raises an important point, could poor home form resulted in their relegations?""")
# Out:
# Both Watford and Leicester City are notable as they generated more xG away from home. Despite this,
# in our dataset they are some of the teams to have been relegated (Watford having one season of data and Leicester City
# having two seasons of data. This raises an important point, could poor home form resulted in their relegations?

# %%
# Analyzing for over or underperformance on expected goals.

# Grouping home xG
home_xg_cal = combined_data.groupby('Home')['xG_H'].sum().reset_index()
home_xg_cal.rename(columns={'xG_H':'Total_xG_H'},inplace=True)

# Grouping away xG
away_xg_cal = combined_data.groupby('Away')['xG_A'].sum().reset_index()
away_xg_cal.rename(columns={'xG_A':'Total_xG_A'},inplace=True)

# Grouping home actual goals
home_goals = combined_data.groupby('Home')['Home_Score'].sum().reset_index()
home_goals.rename(columns={'Home_Score':'Actual_Goals_H'},inplace=True)

# Grouping away actual goals
away_goals = combined_data.groupby('Away')['Away_Score'].sum().reset_index()
away_goals.rename(columns={'Away_Score':'Actual_Goals_A'},inplace=True)

total_xg_cal= pd.merge(home_xg_cal, away_xg_cal, left_on='Home', right_on='Away', how='outer')
total_goals = pd.merge(home_goals, away_goals, left_on='Home', right_on='Away', how='outer')

performance_summary= pd.merge(total_xg_cal, total_goals, on='Home', how='outer')

performance_summary['Total_xG']= performance_summary['Total_xG_H'].fillna(0) + performance_summary['Total_xG_A'].fillna(0)
performance_summary['Total_Goals'] = performance_summary['Actual_Goals_H'].fillna(0) + performance_summary['Actual_Goals_A'].fillna(0)

print(performance_summary)
# Out:
#                Home  Total_xG_H           Away_x  Total_xG_A  Actual_Goals_H  \
# 0           Arsenal       123.2          Arsenal        84.9             136
# 1       Aston Villa        91.8      Aston Villa        65.8             110
# 2       Bournemouth        49.3      Bournemouth        44.9              47
# 3         Brentford        89.0        Brentford        71.5              86
# 4          Brighton        98.1         Brighton        78.0              86
# 5           Burnley        45.3          Burnley        35.1              37
# 6           Chelsea       105.0          Chelsea        82.3             101
# 7    Crystal Palace        75.7   Crystal Palace        58.5              85
# 8           Everton        78.9          Everton        61.3              65
# 9            Fulham        52.3           Fulham        44.8              62
# 10     Leeds United        50.4     Leeds United        40.9              45
# 11   Leicester City        47.6   Leicester City        51.0              57
# 12        Liverpool       144.5        Liverpool       103.5             144
# 13       Luton Town        25.8       Luton Town        16.5              28
# 14  Manchester City       128.9  Manchester City       118.9             169
# 15   Manchester Utd       103.6   Manchester Utd        76.1              99
# 16    Newcastle Utd       111.1    Newcastle Utd        75.2             111
# 17     Norwich City        17.2     Norwich City        15.2              12
# 18  Nott'ham Forest        48.4  Nott'ham Forest        41.1              54
# 19    Sheffield Utd        24.3    Sheffield Utd        14.3              19
# 20      Southampton        42.4      Southampton        40.2              42
# 21        Tottenham       103.9        Tottenham        82.5             113
# 22          Watford        19.8          Watford        20.1              17
# 23         West Ham        81.7         West Ham        71.4              90
# 24           Wolves        63.9           Wolves        57.7              65
#
#              Away_y  Actual_Goals_A  Total_xG  Total_Goals
# 0           Arsenal             104     208.1          240
# 1       Aston Villa              69     157.6          179
# 2       Bournemouth              44      94.2           91
# 3         Brentford              76     160.5          162
# 4          Brighton              83     176.1          169
# 5           Burnley              38      80.4           75
# 6           Chelsea              90     187.3          191
# 7    Crystal Palace              62     134.2          147
# 8           Everton              52     140.2          117
# 9            Fulham              48      97.1          110
# 10     Leeds United              45      91.3           90
# 11   Leicester City              56      98.6          113
# 12        Liverpool             111     248.0          255
# 13       Luton Town              24      42.3           52
# 14  Manchester City             120     247.8          289
# 15   Manchester Utd              73     179.7          172
# 16    Newcastle Utd              86     186.3          197
# 17     Norwich City              11      32.4           23
# 18  Nott'ham Forest              33      89.5           87
# 19    Sheffield Utd              16      38.6           35
# 20      Southampton              37      82.6           79
# 21        Tottenham             100     186.4          213
# 22          Watford              17      39.9           34
# 23         West Ham              72     153.1          162
# 24           Wolves              54     121.6          119

# %%
# Highest Goal Difference (ratio of expected goals to goals scored)
performance_summary['Goal_Difference']=performance_summary['Total_Goals']/performance_summary['Total_xG']
print(performance_summary[['Home','Goal_Difference']].sort_values(by='Goal_Difference', ascending=False))
# Out:
#                Home  Goal_Difference
# 13       Luton Town         1.229314
# 14  Manchester City         1.166263
# 0           Arsenal         1.153292
# 11   Leicester City         1.146045
# 21        Tottenham         1.142704
# 1       Aston Villa         1.135787
# 9            Fulham         1.132853
# 7    Crystal Palace         1.095380
# 23         West Ham         1.058132
# 16    Newcastle Utd         1.057434
# 12        Liverpool         1.028226
# 6           Chelsea         1.019754
# 3         Brentford         1.009346
# 10     Leeds United         0.985761
# 24           Wolves         0.978618
# 18  Nott'ham Forest         0.972067
# 2       Bournemouth         0.966030
# 4          Brighton         0.959682
# 15   Manchester Utd         0.957151
# 20      Southampton         0.956416
# 5           Burnley         0.932836
# 19    Sheffield Utd         0.906736
# 22          Watford         0.852130
# 8           Everton         0.834522
# 17     Norwich City         0.709877

# %%
print("""In football, expected goals provides an insight into a team's attacking performance by 
estimating how many goals they should score based on the quality of their created chances.
A team's ratio being close to 1, indicates that they are scoring at an optimal rate.
While overperfomance ( > 1) can be a good indicator, it may also suggest a regression towards the mean as the season goes on.
In our dataset, Luton Town have an xG/G ratio of 1.23, an overperformance that ultimately led to their relegation.
Earlier on, we could also see that Luton were ranked 21st in total xG generated.
Luton Town are an example of overperformance not always being sustainble for a club's success.
In contrast, teams like Manchester City and Arsenal have remained competitive despite showcasing a slight overperformance in their xG, 
highlighting that overperformance in expected goals is not applicable to all teams in the league.""")
# Out:
# In football, expected goals provides an insight into a team's attacking performance by
# estimating how many goals they should score based on the quality of their created chances.
# A team's ratio being close to 1, indicates that they are scoring at an optimal rate.
# While overperfomance ( > 1) can be a good indicator, it may also suggest a regression towards the mean as the season goes on.
# In our dataset, Luton Town have an xG/G ratio of 1.23, an overperformance that ultimately led to their relegation.
# Earlier on, we could also see that Luton were ranked 21st in total xG generated.
# Luton Town are an example of overperformance not always being sustainble for a club's success.
# In contrast, teams like Manchester City and Arsenal have remained competitive despite showcasing a slight overperformance in their xG,
# highlighting that overperformance in expected goals is not applicable to all teams in the league.
